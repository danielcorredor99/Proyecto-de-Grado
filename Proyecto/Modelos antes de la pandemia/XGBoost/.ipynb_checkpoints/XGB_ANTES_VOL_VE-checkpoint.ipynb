# %% [markdown]
# ## Configuración inicial
#
# A continuación se importan las librerías necesarias para el funcionamiento del notebook.

# %%
#!pip install -r requirements.txt

# %%
#plots and data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#metrics and transformations
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn import metrics

#Model 
import xgboost as xgb

sns.set()

# %%
#function to measure the performance
def timeseries_evaluation_metrics_func(y_true, y_pred,flag):
    def mean_absolute_percentage_error(y_true, y_pred): 
        epsilon=0.1e-5
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    if flag : print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
    else:
        print('Evaluation metric results:')
        print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
        print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
        print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
        print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
        
    return {"MSE":metrics.mean_squared_error(y_true, y_pred),
           "MAE":metrics.mean_absolute_error(y_true, y_pred),
           "RMSE":np.sqrt(metrics.mean_squared_error(y_true, y_pred)),
           "MAPE":mean_absolute_percentage_error(y_true, y_pred)}

# %%
def plot_predict_test(df_test_y,testPredict,lag):
        ### Resultado predicción datos de entrenamiento
    fig, ax = plt.subplots(figsize=[15,8])
    sns.lineplot(df_test_y.flatten(),label="real")
    sns.lineplot(testPredict.flatten(),label="predicción")
    plt.title("Comparación valor real y predicción")
    plt.ylabel("value")

# %%
def createLagFeature(name_features,lag,df):
    for name_feature in name_features:
        for i in range(1,lag+1):
            df[name_feature+"lag"+str(i)]=df[name_feature].shift(i)
    return df

# %% [markdown]
# ---

# %% [markdown]
# ## Cargar y preparar los datos.

# %%
df = pd.read_csv("../../DatasetsDatos_finales/Datos_antes_pandemia/data_antes_vol_var.csv")

df['Fecha'] = pd.to_datetime(df['Fecha'])
df = df.sort_values('Fecha', ascending=True)
df = df.rename(columns = {'Vol. Futuros': 'VolFuturos'})
df
# Out:
#           Fecha  VolFuturos      TRM  Precio Interno
# 0    2010-01-01    0.000000  2044.23        695125.0
# 1    2010-01-02    4.256365  2044.23        695125.0
# 2    2010-01-03    0.794545  2044.23        695125.0
# 3    2010-01-04    0.787899  2044.23        705000.0
# 4    2010-01-05    0.601027  2021.21        690000.0
# ...         ...         ...      ...             ...
# 3648 2019-12-27    4.003614  3281.40        995000.0
# 3649 2019-12-28    2.090121  3294.05        995000.0
# 3650 2019-12-29    0.539108  3294.05        995000.0
# 3651 2019-12-30    1.815513  3294.05        991000.0
# 3652 2019-12-31    1.871355  3277.14        975000.0
#
# [3653 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Desarrollo delo modelo XGBoost

# %%
#objects to scale the data 
sc=StandardScaler()
sc2=StandardScaler()

# %%
df_stats=df

# %%
#
len_data=df_stats.shape[0]

#get target
df_label=df_stats["VolFuturos"].values.reshape(len_data,1)
#get attributes
df_data=df_stats.drop(columns=["Fecha"])

#apply scale
#df_label=sc.fit_transform(df_label)
#df_data_normalize=sc2.fit_transform(df_data)

# %%
def Model(df_data,df_label,lag,estimators):
    delete_columns=list(df_data.columns)
    df_data_lags=createLagFeature(df_data.columns,lag,df_data) if lag>0 else df_data
    df_data_lags.drop(columns=delete_columns,inplace=True)
    df_data_lags=df_data_lags[lag:]
    #transform data
    df_data_lags=sc2.fit_transform(df_data_lags)
    
    #split data
    #last index of the train data
    seventy_percent=int(len_data*0.7)

    #split the data normalize
    df_train=df_data_lags[:seventy_percent]
    df_test=df_data_lags[seventy_percent:]

    #split labels
    df_label=df_label[lag:]
    df_train_y=df_label[:seventy_percent]
    df_test_y=df_label[seventy_percent:]
    #split labels normalize
    df_label_normalize=sc.fit_transform(df_label)
    df_train_y_normalize=df_label_normalize[:seventy_percent]
    df_test_y_normalize=df_label_normalize[seventy_percent:]
    
   
    #make model
    model=xgb.XGBRegressor(n_estimators=estimators
                        ,early_stopping_rounds=80)
    #fit the model with the train data
    
    history=model.fit(df_train,df_train_y_normalize,
          eval_set=[(df_train,df_train_y_normalize),(df_test,df_test_y_normalize)])
   
    # make predictions
    trainPredict = model.predict(df_train)
    trainPredict = np.reshape(trainPredict,(len(trainPredict),1))
    # invert transformation
    trainPredict = sc.inverse_transform(trainPredict)
    trainY = df_train_y
    
    # make predictions
    testPredict = model.predict(df_test)
    # invert transformation
    testPredict = np.reshape(testPredict,(len(testPredict),1))
    testPredict = sc.inverse_transform(testPredict)
    testY = df_test_y
    print("len test: ",testY.shape)
    print("len PREDICT: ",testPredict.shape)
    
    plot_predict_test(df_train_y,trainPredict,lag)
    plot_predict_test(df_test_y,testPredict,lag)
    return [{"Fecha":df_stats.Fecha[lag:][:seventy_percent],"typeXGBoost":["train"]*len(trainPredict.flatten()),"XGBoost" :trainPredict.flatten()}
            ,{"Fecha":df_stats.Fecha[lag:][seventy_percent:],"typeXGBoost":["test"]*len(testPredict.flatten()),"XGBoost":testPredict.flatten()}]
   
    return {"train":timeseries_evaluation_metrics_func(trainY.flatten()+1, trainPredict.flatten()+1,False),
           "test":timeseries_evaluation_metrics_func(testY.flatten()+1, testPredict.flatten()+1,False)}

# %%
lags=[3,5,7,8,10,15]
n_estimators=[i for i in range(50,100,10)]
n_estimators.extend([200,300,500])
results_models={i:{} for i in lags}
for lg in lags:
    for est in n_estimators:
        results_models[lg][est]=Model(df_data.copy(),df_label.copy(),lg,est)
# Out:
# [0]	validation_0-rmse:1.04756	validation_1-rmse:0.97129
# [1]	validation_0-rmse:0.99293	validation_1-rmse:0.92841
# [2]	validation_0-rmse:0.95508	validation_1-rmse:0.89676
# [3]	validation_0-rmse:0.92900	validation_1-rmse:0.88074
# [4]	validation_0-rmse:0.90881	validation_1-rmse:0.87282
# [5]	validation_0-rmse:0.89887	validation_1-rmse:0.87114
# [6]	validation_0-rmse:0.88405	validation_1-rmse:0.87051
# [7]	validation_0-rmse:0.86703	validation_1-rmse:0.87029
# [8]	validation_0-rmse:0.86345	validation_1-rmse:0.86953
# [9]	validation_0-rmse:0.85682	validation_1-rmse:0.86951
# [10]	validation_0-rmse:0.83762	validation_1-rmse:0.87386
# [11]	validation_0-rmse:0.82079	validation_1-rmse:0.87683
# [12]	validation_0-rmse:0.80578	validation_1-rmse:0.87491
# [13]	validation_0-rmse:0.79816	validation_1-rmse:0.87626
# [14]	validation_0-rmse:0.79267	validation_1-rmse:0.87751
# [15]	validation_0-rmse:0.78667	validation_1-rmse:0.87856
# [16]	validation_0-rmse:0.77433	validation_1-rmse:0.87777
# [17]	validation_0-rmse:0.76884	validation_1-rmse:0.87796
# [18]	validation_0-rmse:0.75142	validation_1-rmse:0.88251
# [19]	validation_0-rmse:0.74289	validation_1-rmse:0.88328
# [20]	validation_0-rmse:0.73419	validation_1-rmse:0.88593
# [21]	validation_0-rmse:0.73075	validation_1-rmse:0.88751
# [22]	validation_0-rmse:0.71972	validation_1-rmse:0.88661
# [23]	validation_0-rmse:0.70647	validation_1-rmse:0.89087
# [24]	validation_0-rmse:0.69781	validation_1-rmse:0.89100
# [25]	validation_0-rmse:0.69387	validation_1-rmse:0.89127
# [26]	validation_0-rmse:0.68528	validation_1-rmse:0.89368
# [27]	validation_0-rmse:0.67972	validation_1-rmse:0.89601
# [28]	validation_0-rmse:0.66866	validation_1-rmse:0.89758
# [29]	validation_0-rmse:0.66344	validation_1-rmse:0.90083
# [30]	validation_0-rmse:0.65860	validation_1-rmse:0.90135
# [31]	validation_0-rmse:0.64469	validation_1-rmse:0.90638
# [32]	validation_0-rmse:0.63600	validation_1-rmse:0.90583
# [33]	validation_0-rmse:0.62811	validation_1-rmse:0.90692
# [34]	validation_0-rmse:0.62084	validation_1-rmse:0.90797
# [35]	validation_0-rmse:0.61907	validation_1-rmse:0.90806
# [36]	validation_0-rmse:0.61690	validation_1-rmse:0.90845
# [37]	validation_0-rmse:0.61606	validation_1-rmse:0.90854
# [38]	validation_0-rmse:0.61017	validation_1-rmse:0.91000
# [39]	validation_0-rmse:0.60881	validation_1-rmse:0.91003
# [40]	validation_0-rmse:0.60239	validation_1-rmse:0.91314
# [41]	validation_0-rmse:0.60049	validation_1-rmse:0.91367
# [42]	validation_0-rmse:0.59951	validation_1-rmse:0.91687
# [43]	validation_0-rmse:0.58707	validation_1-rmse:0.92030
# [44]	validation_0-rmse:0.58043	validation_1-rmse:0.92015
# [45]	validation_0-rmse:0.56975	validation_1-rmse:0.92072
# [46]	validation_0-rmse:0.56155	validation_1-rmse:0.92076
# [47]	validation_0-rmse:0.55888	validation_1-rmse:0.92140
# [48]	validation_0-rmse:0.55107	validation_1-rmse:0.92694
# [49]	validation_0-rmse:0.54500	validation_1-rmse:0.92823
# len test:  (1093, 1)
# len PREDICT:  (1093, 1)
# [0]	validation_0-rmse:1.04756	validation_1-rmse:0.97129
# [1]	validation_0-rmse:0.99293	validation_1-rmse:0.92841
# [2]	validation_0-rmse:0.95508	validation_1-rmse:0.89676
# [3]	validation_0-rmse:0.92900	validation_1-rmse:0.88074
# [18]	validation_0-rmse:0.75142	validation_1-rmse:0.88251
# [19]	validation_0-rmse:0.74289	validation_1-rmse:0.88328
# [20]	validation_0-rmse:0.73419	validation_1-rmse:0.88593
# [21]	validation_0-rmse:0.73075	validation_1-rmse:0.88751
# [22]	validation_0-rmse:0.71972	validation_1-rmse:0.88661
# [23]	validation_0-rmse:0.70647	validation_1-rmse:0.89087
# [24]	validation_0-rmse:0.69781	validation_1-rmse:0.89100
# [25]	validation_0-rmse:0.69387	validation_1-rmse:0.89127
# [26]	validation_0-rmse:0.68528	validation_1-rmse:0.89368
# [27]	validation_0-rmse:0.67972	validation_1-rmse:0.89601
# [28]	validation_0-rmse:0.66866	validation_1-rmse:0.89758
# [29]	validation_0-rmse:0.66344	validation_1-rmse:0.90083
# [30]	validation_0-rmse:0.65860	validation_1-rmse:0.90135
# [31]	validation_0-rmse:0.64469	validation_1-rmse:0.90638
# [32]	validation_0-rmse:0.63600	validation_1-rmse:0.90583
# [33]	validation_0-rmse:0.62811	validation_1-rmse:0.90692
# [34]	validation_0-rmse:0.62084	validation_1-rmse:0.90797
# [35]	validation_0-rmse:0.61907	validation_1-rmse:0.90806
# [36]	validation_0-rmse:0.61690	validation_1-rmse:0.90845
# [37]	validation_0-rmse:0.61606	validation_1-rmse:0.90854
# [38]	validation_0-rmse:0.61017	validation_1-rmse:0.91000
# [39]	validation_0-rmse:0.60881	validation_1-rmse:0.91003
# [40]	validation_0-rmse:0.60239	validation_1-rmse:0.91314
# [41]	validation_0-rmse:0.60049	validation_1-rmse:0.91367
# [42]	validation_0-rmse:0.59951	validation_1-rmse:0.91687
# [43]	validation_0-rmse:0.58707	validation_1-rmse:0.92030
# [44]	validation_0-rmse:0.58043	validation_1-rmse:0.92015
# [45]	validation_0-rmse:0.56975	validation_1-rmse:0.92072
# [46]	validation_0-rmse:0.56155	validation_1-rmse:0.92076
# [47]	validation_0-rmse:0.55888	validation_1-rmse:0.92140
# [48]	validation_0-rmse:0.55107	validation_1-rmse:0.92694
# [49]	validation_0-rmse:0.54500	validation_1-rmse:0.92823
# [50]	validation_0-rmse:0.53812	validation_1-rmse:0.92945
# [51]	validation_0-rmse:0.52939	validation_1-rmse:0.93049
# [52]	validation_0-rmse:0.52316	validation_1-rmse:0.93107
# [53]	validation_0-rmse:0.51423	validation_1-rmse:0.93126
# [54]	validation_0-rmse:0.51095	validation_1-rmse:0.93201
# [55]	validation_0-rmse:0.50893	validation_1-rmse:0.93467
# [56]	validation_0-rmse:0.50394	validation_1-rmse:0.93472
# [57]	validation_0-rmse:0.50245	validation_1-rmse:0.93472
# [58]	validation_0-rmse:0.49716	validation_1-rmse:0.93473
# [59]	validation_0-rmse:0.48990	validation_1-rmse:0.93581
# [60]	validation_0-rmse:0.48774	validation_1-rmse:0.93701
# [61]	validation_0-rmse:0.48288	validation_1-rmse:0.93713
# [62]	validation_0-rmse:0.47457	validation_1-rmse:0.94114
# [63]	validation_0-rmse:0.47111	validation_1-rmse:0.94081
# [64]	validation_0-rmse:0.46695	validation_1-rmse:0.94056
# [65]	validation_0-rmse:0.46605	validation_1-rmse:0.94064
# [66]	validation_0-rmse:0.46447	validation_1-rmse:0.94061
# [67]	validation_0-rmse:0.46319	validation_1-rmse:0.94130
# [68]	validation_0-rmse:0.46020	validation_1-rmse:0.94129
# [69]	validation_0-rmse:0.45525	validation_1-rmse:0.94271
# [70]	validation_0-rmse:0.45056	validation_1-rmse:0.94277
# [71]	validation_0-rmse:0.44505	validation_1-rmse:0.94353
# [72]	validation_0-rmse:0.43904	validation_1-rmse:0.94348
# [73]	validation_0-rmse:0.43831	validation_1-rmse:0.94373
# [74]	validation_0-rmse:0.43581	validation_1-rmse:0.94330
# [75]	validation_0-rmse:0.43034	validation_1-rmse:0.94395
# [76]	validation_0-rmse:0.42796	validation_1-rmse:0.94496
# [77]	validation_0-rmse:0.42116	validation_1-rmse:0.94526
# [78]	validation_0-rmse:0.41912	validation_1-rmse:0.94660
# [79]	validation_0-rmse:0.41742	validation_1-rmse:0.94737
# [80]	validation_0-rmse:0.41629	validation_1-rmse:0.94762
# [81]	validation_0-rmse:0.41037	validation_1-rmse:0.94802
# [82]	validation_0-rmse:0.40350	validation_1-rmse:0.94818
# [83]	validation_0-rmse:0.39799	validation_1-rmse:0.94830
# [84]	validation_0-rmse:0.39262	validation_1-rmse:0.94721
# [85]	validation_0-rmse:0.38586	validation_1-rmse:0.94772
# [86]	validation_0-rmse:0.37953	validation_1-rmse:0.94770
# [87]	validation_0-rmse:0.37400	validation_1-rmse:0.94799
# [88]	validation_0-rmse:0.36985	validation_1-rmse:0.94839
# [89]	validation_0-rmse:0.36584	validation_1-rmse:0.94692
# len test:  (1093, 1)
# len PREDICT:  (1093, 1)
# [0]	validation_0-rmse:1.04756	validation_1-rmse:0.97129
# [1]	validation_0-rmse:0.99293	validation_1-rmse:0.92841
# [2]	validation_0-rmse:0.95508	validation_1-rmse:0.89676
# [3]	validation_0-rmse:0.92900	validation_1-rmse:0.88074
# [4]	validation_0-rmse:0.90881	validation_1-rmse:0.87282
# [5]	validation_0-rmse:0.89887	validation_1-rmse:0.87114
# [6]	validation_0-rmse:0.88405	validation_1-rmse:0.87051
# [7]	validation_0-rmse:0.86703	validation_1-rmse:0.87029
# [8]	validation_0-rmse:0.86345	validation_1-rmse:0.86953
# [9]	validation_0-rmse:0.85682	validation_1-rmse:0.86951
# [10]	validation_0-rmse:0.83762	validation_1-rmse:0.87386
# [11]	validation_0-rmse:0.82079	validation_1-rmse:0.87683
# [12]	validation_0-rmse:0.80578	validation_1-rmse:0.87491
# [13]	validation_0-rmse:0.79816	validation_1-rmse:0.87626
# [14]	validation_0-rmse:0.79267	validation_1-rmse:0.87751
# [15]	validation_0-rmse:0.78667	validation_1-rmse:0.87856
# [16]	validation_0-rmse:0.77433	validation_1-rmse:0.87777
# [17]	validation_0-rmse:0.76884	validation_1-rmse:0.87796
# [18]	validation_0-rmse:0.75142	validation_1-rmse:0.88251
# [19]	validation_0-rmse:0.74289	validation_1-rmse:0.88328
# [20]	validation_0-rmse:0.73419	validation_1-rmse:0.88593
# [21]	validation_0-rmse:0.73075	validation_1-rmse:0.88751
# [22]	validation_0-rmse:0.71972	validation_1-rmse:0.88661
# [23]	validation_0-rmse:0.70647	validation_1-rmse:0.89087
# [24]	validation_0-rmse:0.69781	validation_1-rmse:0.89100
# [25]	validation_0-rmse:0.69387	validation_1-rmse:0.89127
# [26]	validation_0-rmse:0.68528	validation_1-rmse:0.89368
# [27]	validation_0-rmse:0.67972	validation_1-rmse:0.89601
# [28]	validation_0-rmse:0.66866	validation_1-rmse:0.89758
# [29]	validation_0-rmse:0.66344	validation_1-rmse:0.90083
# [30]	validation_0-rmse:0.65860	validation_1-rmse:0.90135
# [31]	validation_0-rmse:0.64469	validation_1-rmse:0.90638
# [32]	validation_0-rmse:0.63600	validation_1-rmse:0.90583
# [33]	validation_0-rmse:0.62811	validation_1-rmse:0.90692
# [34]	validation_0-rmse:0.62084	validation_1-rmse:0.90797
# [35]	validation_0-rmse:0.61907	validation_1-rmse:0.90806
# [36]	validation_0-rmse:0.61690	validation_1-rmse:0.90845
# [37]	validation_0-rmse:0.61606	validation_1-rmse:0.90854
# [38]	validation_0-rmse:0.61017	validation_1-rmse:0.91000
# [39]	validation_0-rmse:0.60881	validation_1-rmse:0.91003
# [40]	validation_0-rmse:0.60239	validation_1-rmse:0.91314
# [41]	validation_0-rmse:0.60049	validation_1-rmse:0.91367
# [42]	validation_0-rmse:0.59951	validation_1-rmse:0.91687
# [43]	validation_0-rmse:0.58707	validation_1-rmse:0.92030
# [44]	validation_0-rmse:0.58043	validation_1-rmse:0.92015
# [45]	validation_0-rmse:0.56975	validation_1-rmse:0.92072
# [46]	validation_0-rmse:0.56155	validation_1-rmse:0.92076
# [47]	validation_0-rmse:0.55888	validation_1-rmse:0.92140
# [48]	validation_0-rmse:0.55107	validation_1-rmse:0.92694
# [49]	validation_0-rmse:0.54500	validation_1-rmse:0.92823
# [50]	validation_0-rmse:0.53812	validation_1-rmse:0.92945
# [51]	validation_0-rmse:0.52939	validation_1-rmse:0.93049
# [52]	validation_0-rmse:0.52316	validation_1-rmse:0.93107
# [53]	validation_0-rmse:0.51423	validation_1-rmse:0.93126
# [54]	validation_0-rmse:0.51095	validation_1-rmse:0.93201
# [55]	validation_0-rmse:0.50893	validation_1-rmse:0.93467
# [56]	validation_0-rmse:0.50394	validation_1-rmse:0.93472
# [57]	validation_0-rmse:0.50245	validation_1-rmse:0.93472
# [58]	validation_0-rmse:0.49716	validation_1-rmse:0.93473
# [59]	validation_0-rmse:0.48990	validation_1-rmse:0.93581
# [60]	validation_0-rmse:0.48774	validation_1-rmse:0.93701
# [61]	validation_0-rmse:0.48288	validation_1-rmse:0.93713
# [62]	validation_0-rmse:0.47457	validation_1-rmse:0.94114
# [63]	validation_0-rmse:0.47111	validation_1-rmse:0.94081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fcff5ad7e170> in <module>
#       5 for lg in lags:
#       6     for est in n_estimators:
# ----> 7         results_models[lg][est]=Model(df_data.copy(),df_label.copy(),lg,est)
#
# <ipython-input-10-f2a6afc64eaa> in Model(df_data, df_label, lag, estimators)
#      30     #fit the model with the train data
#      31
# ---> 32     history=model.fit(df_train,df_train_y_normalize,
#      33           eval_set=[(df_train,df_train_y_normalize),(df_test,df_test_y_normalize)])
#      34
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1023                 xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024             )
# -> 1025             self._Booster = train(
#    1026                 params,
#    1027                 train_dmatrix,
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /opt/conda/lib/python3.8/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183         if cb_container.before_iteration(bst, i, dtrain, evals):
#     184             break
# --> 185         bst.update(dtrain, i, obj)
#     186         if cb_container.after_iteration(bst, i, dtrain, evals):
#     187             break
#
# /opt/conda/lib/python3.8/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1916
#    1917         if fobj is None:
# -> 1918             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                                     ctypes.c_int(iteration),
#    1920                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
import json
path="./resultsXGBoost/volatilidadVariablesAntes/"

# %%
for i in lags:
    with open(path+f"lag{i}.json", "w") as outfile:
        json.dump(results_models[i], outfile)

# %%
tesst=Model(df_data.copy(),df_label.copy(),15,50)
# Out:
# [0]	validation_0-rmse:1.03499	validation_1-rmse:0.97275
# [1]	validation_0-rmse:0.94856	validation_1-rmse:0.91781
# [2]	validation_0-rmse:0.88718	validation_1-rmse:0.89850
# [3]	validation_0-rmse:0.85620	validation_1-rmse:0.88162
# [4]	validation_0-rmse:0.81126	validation_1-rmse:0.87306
# [5]	validation_0-rmse:0.78278	validation_1-rmse:0.86758
# [6]	validation_0-rmse:0.75822	validation_1-rmse:0.86747
# [7]	validation_0-rmse:0.74011	validation_1-rmse:0.86519
# [8]	validation_0-rmse:0.72281	validation_1-rmse:0.86313
# [9]	validation_0-rmse:0.71730	validation_1-rmse:0.86159
# [10]	validation_0-rmse:0.71062	validation_1-rmse:0.86258
# [11]	validation_0-rmse:0.70064	validation_1-rmse:0.86319
# [12]	validation_0-rmse:0.68208	validation_1-rmse:0.86416
# [13]	validation_0-rmse:0.66106	validation_1-rmse:0.86428
# [14]	validation_0-rmse:0.63766	validation_1-rmse:0.86654
# [15]	validation_0-rmse:0.63145	validation_1-rmse:0.86605
# [16]	validation_0-rmse:0.62742	validation_1-rmse:0.86668
# [17]	validation_0-rmse:0.61512	validation_1-rmse:0.87027
# [18]	validation_0-rmse:0.59941	validation_1-rmse:0.87181
# [19]	validation_0-rmse:0.58996	validation_1-rmse:0.87180
# [20]	validation_0-rmse:0.58444	validation_1-rmse:0.87359
# [21]	validation_0-rmse:0.58095	validation_1-rmse:0.87345
# [22]	validation_0-rmse:0.57548	validation_1-rmse:0.87323
# [23]	validation_0-rmse:0.56123	validation_1-rmse:0.86879
# [24]	validation_0-rmse:0.55617	validation_1-rmse:0.86863
# [25]	validation_0-rmse:0.53969	validation_1-rmse:0.87199
# [26]	validation_0-rmse:0.52149	validation_1-rmse:0.87148
# [27]	validation_0-rmse:0.51823	validation_1-rmse:0.87090
# [28]	validation_0-rmse:0.51129	validation_1-rmse:0.87043
# [29]	validation_0-rmse:0.50823	validation_1-rmse:0.87149
# [30]	validation_0-rmse:0.49925	validation_1-rmse:0.87342
# [31]	validation_0-rmse:0.48925	validation_1-rmse:0.87354
# [32]	validation_0-rmse:0.47032	validation_1-rmse:0.87475
# [33]	validation_0-rmse:0.46408	validation_1-rmse:0.87481
# [34]	validation_0-rmse:0.45593	validation_1-rmse:0.87539
# [35]	validation_0-rmse:0.45023	validation_1-rmse:0.87481
# [36]	validation_0-rmse:0.44677	validation_1-rmse:0.87517
# [37]	validation_0-rmse:0.44130	validation_1-rmse:0.87511
# [38]	validation_0-rmse:0.43130	validation_1-rmse:0.87864
# [39]	validation_0-rmse:0.42298	validation_1-rmse:0.87938
# [40]	validation_0-rmse:0.41225	validation_1-rmse:0.88002
# [41]	validation_0-rmse:0.40683	validation_1-rmse:0.88093
# [42]	validation_0-rmse:0.40281	validation_1-rmse:0.87846
# [43]	validation_0-rmse:0.39874	validation_1-rmse:0.87921
# [44]	validation_0-rmse:0.39632	validation_1-rmse:0.87952
# [45]	validation_0-rmse:0.38987	validation_1-rmse:0.88085
# [46]	validation_0-rmse:0.38546	validation_1-rmse:0.88095
# [47]	validation_0-rmse:0.37668	validation_1-rmse:0.88133
# [48]	validation_0-rmse:0.36705	validation_1-rmse:0.88124
# [49]	validation_0-rmse:0.36334	validation_1-rmse:0.88056
# len test:  (1081, 1)
# len PREDICT:  (1081, 1)

# %%
finalResult=pd.concat([pd.DataFrame(tesst[0]),pd.DataFrame(tesst[1])])
finalResult
# Out:
#           Fecha typeXGBoost   XGBoost
# 15   2010-01-16       train  1.497147
# 16   2010-01-17       train  1.025188
# 17   2010-01-18       train  0.988501
# 18   2010-01-19       train  1.009465
# 19   2010-01-20       train  0.867937
# ...         ...         ...       ...
# 3648 2019-12-27        test  1.676936
# 3649 2019-12-28        test  2.471510
# 3650 2019-12-29        test  1.275662
# 3651 2019-12-30        test  1.441966
# 3652 2019-12-31        test  1.327042
#
# [3638 rows x 3 columns]

# %%
prev_result=pd.read_csv("VolatilidadVariablesAntes.csv")
prev_result["Fecha"] = prev_result["Fecha"].astype('datetime64[ns]')

# %%
pd.merge(prev_result,finalResult,on="Fecha",how="left").to_csv("VolatilidadVariablesAntes.csv",index=False)
